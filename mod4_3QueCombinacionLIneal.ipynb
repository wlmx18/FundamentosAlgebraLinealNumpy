# %%
"Una combinacion lineal es multiplicar un vector por un escalar y otro vector por otro escalar y sumarlos"
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run "funciones_auxiliares\graficarVectores.ipynb"

# %%
v1 = np.array([3,5])
v2 = np.array([3,2])

v1v2 = v1*2 + v2*3
print(v1v2)
# Out:
# [15 16]

# %%
graficarVectores([v1,v2,v1v2],['orange','blue','red'])
plt.xlim(-1,20)
plt.ylim(-1,20)
# Out:
# (-1.0, 20.0)

# %%
#Regla del paralelogramo
#multiplica el v naranja x2 y ponle encima el v azul*3 llegara al vrojo combinacion lineal

# %%
#definicion de una funcion para graficar todas las posibles combinaciones lineales 
#en esta ocasion un subconjunto de CL nos permitira tener una mejor nocion de la importancia de CL

for a in range(-10,10):
    for b in range(-10,10):
        plt.scatter(v1[0]*a + v2[0]*b,v1[1]*a + v2[1]*b, marker='.',color='orange')
plt.xlim(-100,100)
plt.ylim(-100,100)
plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')

plt.show()

# %%
#Esa es la importancia de las CL con los vectores correctos nos
#permite describir un espacio entero
